# %% [markdown]
# ### Modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn
from sklearn.impute import SimpleImputer
import re

import warnings
warnings.filterwarnings('ignore')

plt.style.use('fivethirtyeight')

# %% [markdown]
# ### Initializing the dataset

# %%
df = pd.read_csv('fifa.csv')
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %% [markdown]
# ### Cleaning the dataframe

# %%
df.columns
df.drop(columns=['Unnamed: 0', 'Photo', 'Flag', 'ID', 'Club Logo', 'Real Face'], inplace=True)
df.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
# 3             De Gea   27       Spain       91         93
# 4       K. De Bruyne   27     Belgium       91         92
#
#                   Club    Value   Wage  Special Preferred Foot  ...  \
# 0         FC Barcelona  €110.5M  €565K     2202           Left  ...
# 1             Juventus     €77M  €405K     2228          Right  ...
# 2  Paris Saint-Germain  €118.5M  €290K     2143          Right  ...
# 3    Manchester United     €72M  €260K     1471          Right  ...
# 4      Manchester City    €102M  €355K     2281          Right  ...
#
#    Composure  Marking  StandingTackle SlidingTackle GKDiving GKHandling  \
# 0       96.0     33.0            28.0          26.0      6.0       11.0
# ...

# %% [markdown]
# ### Looking for null values

# %%
df.isnull().sum()
# df.shape

imputer = SimpleImputer(missing_values=np.nan, strategy="constant", fill_value='€ 5M')
df["Release Clause"] = imputer.fit_transform( df[["Release Clause"]])

df.isnull().sum()
# Out:
# Name               0
# Age                0
# Nationality        0
# Overall            0
# Potential          0
#                   ..
# GKHandling        48
# GKKicking         48
# GKPositioning     48
# GKReflexes        48
# Release Clause     0
# Length: 83, dtype: int64

# %% [markdown]
# ### Looking at the Five Points Summary

# %%
df.describe()
# Out:
#                 Age       Overall     Potential       Special  \
# count  18207.000000  18207.000000  18207.000000  18207.000000
# mean      25.122206     66.238699     71.307299   1597.809908
# std        4.669943      6.908930      6.136496    272.586016
# min       16.000000     46.000000     48.000000    731.000000
# 25%       21.000000     62.000000     67.000000   1457.000000
# 50%       25.000000     66.000000     71.000000   1635.000000
# 75%       28.000000     71.000000     75.000000   1787.000000
# max       45.000000     94.000000     95.000000   2346.000000
#
#        International Reputation     Weak Foot   Skill Moves  Jersey Number  \
# count              18159.000000  18159.000000  18159.000000   18147.000000
# mean                   1.113222      2.947299      2.361308      19.546096
# std                    0.394031      0.660456      0.756164      15.947765
# min                    1.000000      1.000000      1.000000       1.000000
# ...

# %% [markdown]
# ### Relationship between Player Potential and Age

# %%
sbn.jointplot(data=df, x='Age', y='Potential', 
              joint_kws={'alpha':0.1, 's':3, 'color':'blue'}, marginal_kws={'color':'green'})
plt.show()

# %% [markdown]
# Player Potential decreases with Age.

# %% [markdown]
# ### Relationship between Sprint speed and Age

# %%
sbn.lmplot(data=df, x='Age', y='SprintSpeed', lowess=True, 
           scatter_kws={'alpha':0.01, 's':3, 'color':'red'}, 
           line_kws={'color':'black', 'linewidth':1})
plt.show()

# %% [markdown]
# Sprint Speed decreases with increase in Age

# %% [markdown]
# ### Which Foot do players prefer?

# %%
sbn.lmplot(data=df, x='BallControl', y='Dribbling', col='Preferred Foot', 
           scatter_kws={'alpha':0.1, 'color':'green'}, line_kws={'color':'red', 'linewidth':2})
plt.show()

# %% [markdown]
# Most of the players prefer Right Foot.
# Dribbling increases with increase in Ball Control.

# %% [markdown]
# ### Relationship between Scores & Age with Foot

# %%
plt.figure(figsize=(15, 8))
sbn.boxplot(data=df, x='Overall', y='Age', hue='Preferred Foot',
           palette='rocket')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The difference is negligible but the right footed players are performing slightly better than the left footed players.
